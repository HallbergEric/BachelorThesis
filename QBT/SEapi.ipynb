# %%
from stackapi import StackAPI
import pandas as pd
import json

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('posts', fromdate=1457136000, todate=1457222400,
min=20, tagged='serverless')

print(questions)
# Out:
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 159, 'total': 0, 'items': [{'owner': {'reputation': 526856, 'user_id': 939860, 'user_type': 'registered', 'accept_rate': 100, 'profile_image': 'https://www.gravatar.com/avatar/ed7cecf2bd835cf5670d271d0d104f51?s=256&d=identicon&r=PG', 'display_name': 'Erwin Brandstetter', 'link': 'https://stackoverflow.com/users/939860/erwin-brandstetter'}, 'score': 8, 'last_edit_date': 1647622944, 'last_activity_date': 1647622944, 'creation_date': 1457138178, 'post_type': 'answer', 'post_id': 35808554, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/a/35808554'}, {'owner': {'reputation': 2120, 'user_id': 1422645, 'user_type': 'registered', 'accept_rate': 50, 'profile_image': 'https://www.gravatar.com/avatar/dc7ae173442d93bf26fc8c2669e64f8e?s=256&d=identicon&r=PG', 'display_name': 'Natanael', 'link': 'https://stackoverflow.com/users/1422645/natanael'}, 'score': 19, 'last_edit_date': 1532621532, 'last
# ...

# %%
print(type(questions))
app_json = json.dumps(questions)
print(len(questions.get("items")))
# Out:
# <class 'dict'>
# 500
